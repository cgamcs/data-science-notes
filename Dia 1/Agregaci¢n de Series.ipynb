# %%
import pandas as pd

numeros = pd.Series([10, 20, 30, 40, 50])
numeros
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
promedio = numeros.mean()
print(f'El promedio es {promedio}')
# Out:
# El promedio es 30.0

# %%
total = numeros.sum()
total
# Out:
# np.int64(150)

# %%
maximo = numeros.max()
maximo
# Out:
# 50

# %%
minimo = numeros.min()
minimo
# Out:
# 10
