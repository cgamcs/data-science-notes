# %%
import pandas as pd

# %%
serie = pd.Series([10, 20, 30, 40, 50])
serie
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
serie[0] = serie[0] + 10
serie
# Out:
# 0    20
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
serie = serie + 10
serie
# Out:
# 0    30
# 1    30
# 2    40
# 3    50
# 4    60
# dtype: int64

# %%
serie = serie * 2

# %%
serie
# Out:
# 0     60
# 1     60
# 2     80
# 3    100
# 4    120
# dtype: int64
